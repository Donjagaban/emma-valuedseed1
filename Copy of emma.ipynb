# %%
name = 'emmanuel'
age = 56
Rt = 7.09
Ball = True

# %%
print(type(name))
print(type(age))
print(type(Rt))
print(type(Ball))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
str(age) # converting integer to string
# Out:
# '56'

# %%
float(age) # converting integer to float
# Out:
# 56.0

# %%
bool(age) # converting to boolan
# Out:
# True

# %%
bool(name) # converting string to boolean
# Out:
# True

# %%
str(bool) # converting boolean to srting
# Out:
# "<class 'bool'>"

# %%
bool(int) # converting boolean to integer
# Out:
# True

# %%
bool(name) # converting boolean to string
# Out:
# True
